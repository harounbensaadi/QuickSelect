# %% [markdown]
# # QuickSelect
#
# ### A user-friendly interface for simplified well selection across multiple plate configurations in a Python environment.
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Author: Haroun Taki Eddine Bensaadi
#
# Email: hte.bensaadi@gmail.com
#
# ### Functionalities
#
# **Various Plate Sizes**: including 6, 12, 24, 48, 96, and 384 well plates.
#
# **Easy Integration**: Embed directly in Jupyter notebooks with a single line of code.
#
# **Drag-to-Select**: Simplifies well selection through intuitive drag interactions.
#
# **Interactive Interface**: Engages users dynamic, responsive layout and intuitive UI.
#
# **Unlimited Liquid Types**: Accommodates any number of liquid types for complex designs.
#
# **Real-Time Layouts**: Shows selected wells dynamically, simplifying experimental visualization.
#
# **Export**: Offers export options in both Python and JavaScript formats.

# %%
from quick_select import QuickSelect

# %%
plate_1 = QuickSelect().renderPlate(QuickSelect.PLATE_6_WELLS)
plate_2 = QuickSelect().renderPlate(QuickSelect.PLATE_12_WELLS)
plate_3 = QuickSelect().renderPlate(QuickSelect.PLATE_24_WELLS)
plate_4 = QuickSelect().renderPlate(QuickSelect.PLATE_48_WELLS)
plate_5 = QuickSelect().renderPlate(QuickSelect.PLATE_96_WELLS)
plate_6 = QuickSelect().renderPlate(QuickSelect.PLATE_384_WELLS)
# Out:
#         <iframe
#             width="1200"
#             height="700"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="1200"
#             height="700"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="1200"
#             height="700"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="1200"
#             height="700"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="1200"
#             height="700"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="1200"
#             height="700"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
